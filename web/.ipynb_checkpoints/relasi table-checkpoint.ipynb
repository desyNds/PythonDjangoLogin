# %%
from django.contrib.auth.models import User
from orm_models import Member, Club, CityDistrict

# %%
cd = CityDistrict()
cd.name = 'Mataram'
cd.save()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     327         query = self.convert_query(query)
# --> 328         return Database.Cursor.execute(self, query, params)
#     329
#
# OperationalError: no such table: city_district
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-0301a7819afb> in <module>()
#       1 cd = CityDistrict()
#       2 cd.name = 'Mataram'
# ----> 3 cd.save()
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/base.py in save(self, force_insert, force_update, using, update_fields)
#     804
#     805         self.save_base(using=using, force_insert=force_insert,
# --> 806                        force_update=force_update, update_fields=update_fields)
#     807     save.alters_data = True
#     808
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     834             if not raw:
#     835                 self._save_parents(cls, using, update_fields)
# --> 836             updated = self._save_table(raw, cls, force_insert, force_update, using, update_fields)
#     837         # Store the database on which the object was saved
#     838         self._state.db = using
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/base.py in _save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#     920
#     921             update_pk = meta.auto_field and not pk_set
# --> 922             result = self._do_insert(cls._base_manager, using, fields, update_pk, raw)
#     923             if update_pk:
#     924                 setattr(self, meta.pk.attname, result)
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/base.py in _do_insert(self, manager, using, fields, update_pk, raw)
#     959         """
#     960         return manager._insert([self], fields=fields, return_id=update_pk,
# --> 961                                using=using, raw=raw)
#     962
#     963     def delete(self, using=None, keep_parents=False):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/query.py in _insert(self, objs, fields, return_id, raw, using)
#    1058         query = sql.InsertQuery(self.model)
#    1059         query.insert_values(fields, objs, raw=raw)
# -> 1060         return query.get_compiler(using=using).execute_sql(return_id)
#    1061     _insert.alters_data = True
#    1062     _insert.queryset_only = False
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/sql/compiler.py in execute_sql(self, return_id)
#    1097         with self.connection.cursor() as cursor:
#    1098             for sql, params in self.as_sql():
# -> 1099                 cursor.execute(sql, params)
#    1100             if not (return_id and cursor):
#    1101                 return
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      78         start = time()
#      79         try:
# ---> 80             return super(CursorDebugWrapper, self).execute(sql, params)
#      81         finally:
#      82             stop = time()
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      92                 if dj_exc_type not in (DataError, IntegrityError):
#      93                     self.wrapper.errors_occurred = True
# ---> 94                 six.reraise(dj_exc_type, dj_exc_value, traceback)
#      95
#      96     def __call__(self, func):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/utils/six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     326             return Database.Cursor.execute(self, query)
#     327         query = self.convert_query(query)
# --> 328         return Database.Cursor.execute(self, query, params)
#     329
#     330     def executemany(self, query, param_list):
#
# OperationalError: no such table: city_district

# %%
cd = CityDistrict()
cd.name = 'Lombok Tengah'
cd.save()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     327         query = self.convert_query(query)
# --> 328         return Database.Cursor.execute(self, query, params)
#     329
#
# OperationalError: no such table: city_district
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-037a2cd01b09> in <module>()
#       1 cd = CityDistrict()
#       2 cd.name = 'Lombok Tengah'
# ----> 3 cd.save()
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/base.py in save(self, force_insert, force_update, using, update_fields)
#     804
#     805         self.save_base(using=using, force_insert=force_insert,
# --> 806                        force_update=force_update, update_fields=update_fields)
#     807     save.alters_data = True
#     808
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/base.py in save_base(self, raw, force_insert, force_update, using, update_fields)
#     834             if not raw:
#     835                 self._save_parents(cls, using, update_fields)
# --> 836             updated = self._save_table(raw, cls, force_insert, force_update, using, update_fields)
#     837         # Store the database on which the object was saved
#     838         self._state.db = using
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/base.py in _save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#     920
#     921             update_pk = meta.auto_field and not pk_set
# --> 922             result = self._do_insert(cls._base_manager, using, fields, update_pk, raw)
#     923             if update_pk:
#     924                 setattr(self, meta.pk.attname, result)
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/base.py in _do_insert(self, manager, using, fields, update_pk, raw)
#     959         """
#     960         return manager._insert([self], fields=fields, return_id=update_pk,
# --> 961                                using=using, raw=raw)
#     962
#     963     def delete(self, using=None, keep_parents=False):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/query.py in _insert(self, objs, fields, return_id, raw, using)
#    1058         query = sql.InsertQuery(self.model)
#    1059         query.insert_values(fields, objs, raw=raw)
# -> 1060         return query.get_compiler(using=using).execute_sql(return_id)
#    1061     _insert.alters_data = True
#    1062     _insert.queryset_only = False
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/sql/compiler.py in execute_sql(self, return_id)
#    1097         with self.connection.cursor() as cursor:
#    1098             for sql, params in self.as_sql():
# -> 1099                 cursor.execute(sql, params)
#    1100             if not (return_id and cursor):
#    1101                 return
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      78         start = time()
#      79         try:
# ---> 80             return super(CursorDebugWrapper, self).execute(sql, params)
#      81         finally:
#      82             stop = time()
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      92                 if dj_exc_type not in (DataError, IntegrityError):
#      93                     self.wrapper.errors_occurred = True
# ---> 94                 six.reraise(dj_exc_type, dj_exc_value, traceback)
#      95
#      96     def __call__(self, func):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/utils/six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     326             return Database.Cursor.execute(self, query)
#     327         query = self.convert_query(query)
# --> 328         return Database.Cursor.execute(self, query, params)
#     329
#     330     def executemany(self, query, param_list):
#
# OperationalError: no such table: city_district

# %%
cd = CityDistrict()
cd.name = 'Lombok Timur'
cd.save()

# %%
ct = CityDistrict.objects.filter(name='Mataram').first()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     327         query = self.convert_query(query)
# --> 328         return Database.Cursor.execute(self, query, params)
#     329
#
# OperationalError: no such table: city_district
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-66a6478ee9f9> in <module>()
# ----> 1 ct = CityDistrict.objects.filter(name='Mataram').first()
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/query.py in first(self)
#     559         Returns the first object of a query, returns None if no match is found.
#     560         """
# --> 561         objects = list((self if self.ordered else self.order_by('pk'))[:1])
#     562         if objects:
#     563             return objects[0]
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/query.py in __iter__(self)
#     248                - Responsible for turning the rows into model objects.
#     249         """
# --> 250         self._fetch_all()
#     251         return iter(self._result_cache)
#     252
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/query.py in _fetch_all(self)
#    1100     def _fetch_all(self):
#    1101         if self._result_cache is None:
# -> 1102             self._result_cache = list(self._iterable_class(self))
#    1103         if self._prefetch_related_lookups and not self._prefetch_done:
#    1104             self._prefetch_related_objects()
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/query.py in __iter__(self)
#      51         # Execute the query. This will also fill compiler.select, klass_info,
#      52         # and annotations.
# ---> 53         results = compiler.execute_sql(chunked_fetch=self.chunked_fetch)
#      54         select, klass_info, annotation_col_map = (compiler.select, compiler.klass_info,
#      55                                                   compiler.annotation_col_map)
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/models/sql/compiler.py in execute_sql(self, result_type, chunked_fetch)
#     874             cursor = self.connection.cursor()
#     875         try:
# --> 876             cursor.execute(sql, params)
#     877         except Exception:
#     878             try:
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      78         start = time()
#      79         try:
# ---> 80             return super(CursorDebugWrapper, self).execute(sql, params)
#      81         finally:
#      82             stop = time()
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      92                 if dj_exc_type not in (DataError, IntegrityError):
#      93                     self.wrapper.errors_occurred = True
# ---> 94                 six.reraise(dj_exc_type, dj_exc_value, traceback)
#      95
#      96     def __call__(self, func):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/utils/six.py in reraise(tp, value, tb)
#     683             value = tp()
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#     687
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      63                 return self.cursor.execute(sql)
#      64             else:
# ---> 65                 return self.cursor.execute(sql, params)
#      66
#      67     def executemany(self, sql, param_list):
#
# /opt/anaconda3/envs/latihan/lib/python3.5/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     326             return Database.Cursor.execute(self, query)
#     327         query = self.convert_query(query)
# --> 328         return Database.Cursor.execute(self, query, params)
#     329
#     330     def executemany(self, query, param_list):
#
# OperationalError: no such table: city_district

# %%
cl = Club()
cl.name = 'Arrihu Archery'
cl.register_number = '286475'
cl.since = '2013'
cl.secretariat = 'Jl. Musium no 19 A'
cl.city_district = ct
cl.leader = 'Lalu Erfandi'
cl.slogan = 'Ayo Memanah Ayo Hidupkan Sunnah'
cl.save()
